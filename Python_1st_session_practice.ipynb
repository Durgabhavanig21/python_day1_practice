# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgabhavanig21/python_day1_practice/blob/main/Python_1st_session_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # python day1 practice

# %% [markdown]
# 1. Write a program to take your name as input and print a greeting message

# %%
name = input("Enter your name:")
print("Hello",name)
# Out:
# Enter your name:Bannu
# Hello Bannu

# %% [markdown]
# 2.  Take two numbers as input and print their sum.

# %%
x= int(input("Enter 1st num: "))
y= int(input("Enter 2nd num: "))
print(x+y)
# Out:
# Enter 1st num: 109
# Enter 2nd num: 28
# 137

# %% [markdown]
# 3.Write a program to check the data type of a variable entered by the user.

# %%
a = input("enter a num: ")
print(type(a))

b = int(input("Enter a num"))
print(type(b))
type(b)
# Out:
# enter a num: 10
# <class 'str'>
# Enter a num22
# <class 'int'>
# int

# %% [markdown]
# 4. Take a string input and print it in uppercase and lowercase.

# %%
name = "Bannu"
print(name.upper())
print(name.lower())
print(name.title())
# Out:
# BANNU
# bannu
# Bannu

# %% [markdown]
# 5. Write a program to count the number of characters in a string.

# %%
name ="I am Durga Bhavani"
print(len(name))
# Out:
# 18

# %% [markdown]
# 6. Take a string and replace all spaces with underscores (_)

# %%
STRING = input("Enter a string")
print(STRING.replace(" ","_"))
# Out:
# Enter a stringI am Durga
# I_am_Durga

# %% [markdown]
# 7. Write a program to extract the first and last character of a string.

# %%
text = "Durga Bhavani"
print(text[0])
print(text[-1])
print(text[0],text[-1])
text[0:-1] #practice
# Out:
# D
# i
# D i
# 'Durga Bhavan'

# %% [markdown]
# 8. Take user input and print it using formatted string (f-string).

# %%
Text = input("Enter a string")
print("Hello {Text}")
print(f"Hello {Text}")
# Out:
# Enter a stringWorld
# Hello {Text}
# Hello World

# %% [markdown]
# 9. Write a program to concatenate two strings entered by the user.

# %%
Text1 = input("Enter text1")
Text2 = input("Enter text2")
print(Text1 + Text2)
# Out:
# Enter text1python
# Enter text2is a  OOP language
# python is a  OOP language

# %% [markdown]
# 10. Take a sentence and remove leading and trailing spaces.

# %%
Text = "  python  "
print(Text.strip())
print(Text.lstrip())
print(Text.rstrip())
# Out:
# python
# python
#   python

# %% [markdown]
# 11. Banking: Take customer name and account balance, and print a welcome message with
# balance.

# %%
CustomerName =input("Enter your name: ")
AccountBalance = float(input("Enter your balance: "))
print(f"Welcome {CustomerName},your balance is {AccountBalance} ")
# Out:
# Enter your name: Bannu
# Enter your balance: 9000
# Welcome Bannu,your balance is 9000.0

# %% [markdown]
# 12. E-commerce: Take product name and price, apply 10% discount and print final price.

# %%
ProductName = input("Enter product name: ")
Price = float(input("Enter the price: "))
Discount = Price *0.10
total = Price - Discount

print(f"Final price of{ProductName} after discount is {total}")
# Out:
# Enter product name: Dress
# Enter the price: 600
# Final price ofDress after discount is 540.0

# %% [markdown]
# 13. Healthcare: Take patient name and age, print formatted health record message.
# **bold text**

# %%
PatientName = input("Enter patient name: ")
Age = input("Enter patient age: ")

print(f"Patient Name: {PatientName},Age: {Age}.Health record is created")
# Out:
# Enter patient name: keerthi
# Enter patient age: 30
# Patient Name: keerthi,Age: 30.Health record is created

# %% [markdown]
# 14.Education: Take student name and marks, print a formatted report.

# %%
Name = input("Enter student name: ")
marks = input("Enter marks: ")
print(f"Student name: {Name},marks: {marks}")
# Out:
# Enter student name: jay
# Enter marks: 60
# Student name: jay,marks: 60

# %% [markdown]
# 15. Travel: Take city name and print a welcome message in uppercase.

# %%
cityName = input("Enter city name: ")
print(f"Welcom to {cityName.upper()}")
# Out:
# Enter city name: Chennai
# Welcom to CHENNAI

# %% [markdown]
# 16. HR System: Take employee name and role, print a formatted introduction.

# %%
EmployeeName = input("Enter name: ")
role = input("Enter role: ")
print(f"My name is {EmployeeName} and i worked as a {role}")
# Out:
# Enter name: Bannu
# Enter role: Software Engineer
# My name is Bannu and i worked as a Software Engineer

# %% [markdown]
# 17. Food Delivery: Take food item and quantity, print order summary.

# %%
FoodItem = input("Enter food item: ")
quantity = input("Enter quantity: ")

print(f"Order Summary: {quantity} x {FoodItem} ordered successfully!")
# Out:
# Enter food item: Burger
# Enter quantity: 3
# Order Summary: 3 x Burger ordered successfully!

# %% [markdown]
# 18. Login System: Take username and remove extra spaces using strip().

# %%
userName = input("Enter username: ")
print(userName.strip())
print(userName.lstrip())
print(userName.rstrip())
# Out:
# Enter username:       Bannu_21
# Bannu_21
# Bannu_21
#       Bannu_21

# %% [markdown]
# 19. Data Cleaning: Take a string and replace special characters (#, @) with empty string.

# %%
text1 = input("Enter a string: ")
text2 = input("Enter another string")
print(text1.replace(" ","#"))
print(text2.replace(" ","@"))
# Out:
# Enter a string:  hello world
# Enter another string i am python
# #hello#world
# @i@am@python

# %% [markdown]
# 20. Chat Application: Take user message and print it in title case.

# %%
message = input("Enter a message: ")
message.title()
# Out:
# Enter a message: hello, how are you ?
# 'Hello, How Are You ?'
